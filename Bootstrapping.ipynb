# %%
import pandas as pd

# Step 1: Load the original data (replace with the path to your file)
data = pd.read_excel('Dataset.xlsx')  # Replace 'your_survey_data.xlsx' with your actual file path

# Step 2: Perform bootstrapping (sample 1000 records with replacement)
survey = data.sample(n=1000, replace=True, random_state=42)

# Step 3: Check the first few rows of the bootstrapped data to confirm
print(survey.head())
survey.to_csv('survey.csv',index=False)

# Step 4: Save the new bootstrapped dataset to an Excel or CSV file
# Out:
#                   Timestamp Gender Age group Profession  \
# 102 2025-01-14 23:49:12.926   Male     20-30   Employed
# 92  2025-01-15 09:35:59.793   Male       >50   Employed
# 14  2025-01-15 21:35:57.252   Male       >50   Employed
# 106 2025-01-14 23:20:36.563   Male       <20    Student
# 71  2025-01-15 12:43:58.809   Male       >50   Employed
#
#     Average screen time on daily basis (phone or laptop)  \
# 102                                          6-8 hours
# 92                                            8+ hours
# 14                                            8+ hours
# 106                                          4-6 hours
# 71                                            2-4hours
#
#     Average time spent on social media on daily basis  \
# 102                                         < 2 hours
# 92                                           8+ hours
# 14                                          < 2 hours
# 106                                         < 2 hours
# ...

# %%
data1=pd.read_csv('Impact_of_Mobile_Phone_on_Students_Health.csv')
data1.shape
# Out:
# (100, 20)

# %%
student_health = data1.sample(n=1000, replace=True, random_state=42)
student_health.head()
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 51      Amir  21-25    Male           Yes                  Android
# 92  Iftikhar  21-25    Male           Yes                  Android
# 14    Saleem  21-25    Male           Yes                  Android
# 71     Jawed  26-30    Male           Yes                  Android
# 60     Aryan  21-25    Male           Yes                  Android
#
#    Mobile phone use for education  \
# 51                      Sometimes
# 92                      Sometimes
# 14                      Sometimes
# 71                         Rarely
# 60                      Sometimes
#
#                              Mobile phone activities Helpful for studying  \
# 51                                      All of these                  Yes
# 92                                      All of these                   No
# 14  Social Media;Web-browsing;Messaging;All of these                  Yes
# ...

# %%
student_health.shape
# Out:
# (1000, 20)

# %%
student_health.to_csv('student_health.csv', index=False)
